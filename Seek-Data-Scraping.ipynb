# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from bs4 import BeautifulSoup
import requests
import re

# import sleep
from time import sleep

plt.style.use('fivethirtyeight')

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
def getting_data(url):
    ###
    ###  This function send request to the web server
    ###  Get the response back, Check Status Code
    ###  Grab HTML and turns it to Beautiful Soup
    ###
    
    #send request to the url given
    response = requests.get(url)
    
    if response.status_code == 200:
        #received the data basck
        html = response.text
    
        #parse HTML to Beautiful Soup
        soup = BeautifulSoup(html, 'lxml')
    
        return soup
    
    else:
        return None

# %%
def get_job_summary(link):
    
    ###
    ###  This function get the Link to the Job Ad
    ###  Get the response back and Extract Job Summary
    ###  Turns it to Beautiful Soup and Extract Text
    ###
    
    # open that page and get the job summary
    url = baseurl + link
    soup = getting_data(url)
    
    try:
        jobDescription = soup.find('div', {'data-automation':'mobileTemplate'})
        
        return jobDescription.get_text()
        
    except:
        
        return None

# %%
def get_job_details(job_article):
    
    ###
    ###  Each job advertised on Seek on the list displayed is called Article
    ###  This function receive one article at a time to extract job related info
    ###  Then return it as a list of data
    ###
    
    
    try:
        #send one job article at a time to extract each job data
        job_ad = job_article.find('a', {'data-automation':'jobTitle'})
        title = job_ad.text
        link = job_ad['href']
        #print ( 'title:', title)
        #print ( 'link:', link)

        job_ad = job_article.find('span', {'data-automation':'jobSalary'})
        if (job_ad is None):
            salary = 'NA'
        else:
            salary = job_ad.text
        #print ('salary:', salary)

        job_ad = job_article.find('a', {'data-automation':'jobCompany'})
        if (job_ad is None):
            company = 'NA'
        else:
            company = job_ad.text
        #print ('company:', company)

        job_ad = job_article.find('a', {'data-automation':'jobLocation'})
        if (job_ad is None):
            location = 'NA'
        else:
            location = job_ad.text
        #print ('location:', location)


        job_ad = job_article.find('a', {'data-automation':'jobClassification'})
        if (job_ad is None):
            classification = 'NA'
        else:
            classification = job_ad.text
        #print ('classification:', classification)
        
        
        jobsummary = get_job_summary(link)
        
        return [title, link, salary, location, company, classification, jobsummary]

    except:
        
        return None

# %%
def get_job_ads_no(jobSearch):
    
    job_listings = []
    
    
    #send the html request for this job search
    html = getting_data(jobSearch + '1')
    
    # get no of toal jobs found
    jobcounts = html.find('strong',{'data-automation':'totalJobsCount'})
    
    # extract the jobs no
    jobsfound = int(jobcounts.text.replace(",", ""))

    #calculate how many pages need to collect the job listing
    pages =  int(jobsfound / 20) + 1
    
    print (jobsfound, pages)
    
    
    return pages

# %%
def get_job_articles(jobSearch, startPage, endPage):
    
    articleList = []
    # getting job listing for each page
    # each job is an article
    for p in np.arange(startPage,endPage):

        pageUrl = jobSearch + str(p + 1)
        print (pageUrl)
        
        # wait one second before getting a page
        sleep(1)
        html = getting_data(pageUrl)
        
        # find each job listing
        articleListPreminum = html.find_all('article',{'data-automation':'premiumJob'})
        articleList.extend(articleListPreminum)
        
        articleListNormal = html.find_all('article',{'data-automation':'normalJob'})
        articleList.extend(articleListNormal)
    
    return articleList

# %%
def get_df_Article(articleList):

    ###
    ###  This function recieved list of articles, then split the article list into half
    ###  Then feed an article at a time into another function to extract job info
    ###  Once processed return dataframes
    ###
    # ------------------------------------------------
    # Process the articles
    # ------------------------------------------------   
    job_postings = []
    
    for i in range(len(articleList)):
        new_postings = get_job_details(articleList[i])
        
        if new_postings is not None:
            job_postings.append(new_postings)    
    
    #print (len(job_postings))
    
    # now create a dataframe frome the data
    df = pd.DataFrame(job_postings, columns=['title', 'link', 'salary', 'location', 'company', 'classification', 'summary'])
    
    print ('finish process article')
    
    
    return df

# %%
### 
### Define variables related to the URL for web scraping on SEEK
### Each sets are group based on Salary and to make it scrape in smaller chunks
###
baseurl = "https://www.seek.com.au/"

sixty_suffix = '?salarytype=annual&page='
eighty_suffix = '?salaryrange=60000-80000&salarytype=annual&page='
hundred_suffix = '?salaryrange=80000-100000&salarytype=annual&page='
onetwenty_suffix = '?salaryrange=100000-120000&salarytype=annual&page='
onefifty_suffix = '?salaryrange=120000-150000&salarytype=annual&page='
twohundred_suffix = '?salaryrange=150000-200000&salarytype=annual&page='
twofifty_suffix = '?salaryrange=200000-999999&salarytype=annual&page='

dataUrl = baseurl + "software-engineer-jobs/in-New-South-Wales-NSW/"

dataSixty = dataUrl + sixty_suffix
dataEighty = dataUrl + eighty_suffix
dataHundred = dataUrl + hundred_suffix
dataOnetwenty = dataUrl + onetwenty_suffix
dataOnefifty = dataUrl + onefifty_suffix
dataTwohundred = dataUrl + twohundred_suffix
dataTwofifty = dataUrl + twofifty_suffix

# %%
# For those salary between 0 - 60K

# get job ads numbers
pages = get_job_ads_no(dataSixty)

# get articles in chucks based on number of pages, make it 10 pages or 200~220 jobs increment at a time
for startPage in np.arange(0, pages, 10):
    
    endPage = startPage + 10
    articleList = get_job_articles(dataSixty, startPage, endPage)
    
    # sometimes Seek cuts off the link - no more articles are returned
    if not articleList:
        print("List is empty")
        #break
    else:
        new_df = get_df_Article(articleList)
        if startPage == 0:
            df = new_df
        else:
            df = pd.concat([df, new_df])
            print(len(df))
# Out:
# 2238 112
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=1
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=2
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=3
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=4
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=5
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=6
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=7
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=8
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=9
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=10
# finish process article
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=11
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=12
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=13
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=14
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=15
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=16
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=17
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=18
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=19
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=20
# finish process article
# 440
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=21
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=22
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=23
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=24
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=25
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=26
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=27
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=28
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=29
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=30
# finish process article
# 660
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=31
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=32
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=33
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=34
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=35
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=36
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=37
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=38
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=39
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=40
# finish process article
# 870
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=41
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=42
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=43
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=44
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=45
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=46
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=47
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=48
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=49
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=50
# finish process article
# 1070
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=51
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=52
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=53
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=54
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=55
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=56
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=57
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=58
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=59
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=60
# finish process article
# 1270
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=61
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=62
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=63
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=64
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=65
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=66
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=67
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=68
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=69
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=70
# finish process article
# 1470
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=71
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=72
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=73
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=74
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=75
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=76
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=77
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=78
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=79
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=80
# finish process article
# 1670
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=81
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=82
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=83
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=84
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=85
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=86
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=87
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=88
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=89
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=90
# finish process article
# 1870
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=91
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=92
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=93
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=94
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=95
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=96
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=97
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=98
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=99
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=100
# finish process article
# 2072
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=101
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=102
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=103
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=104
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=105
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=106
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=107
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=108
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=109
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=110
# finish process article
# 2290
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=111
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=112
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=113
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=114
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=115
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=116
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=117
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=118
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=119
# https://www.seek.com.au/software-engineer-jobs/in-New-South-Wales-NSW/?salarytype=annual&page=120
# finish process article
# 2348

# %%
df.to_csv('./datasets/dataSixty.csv')
df.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-37-db53298cd9bf> in <module>
# ----> 1 df.to_csv('./datasets/dataSixty.csv')
#       2 df.shape
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/csvs.py in save(self)
#     226         """
#     227         # apply compression and byte/text conversion
# --> 228         with get_handle(
#     229             self.filepath_or_buffer,
#     230             self.mode,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: './datasets/dataSixty.csv'
